# %%
# !pip install casparser
import pandas as pd
from IPython.display import display, HTML
import pprint
import casparser
import json

data = casparser.read_cas_pdf("stmt3.pdf", "Fastrack@12")
# print(type(data))
print(data)
# df = pd.DataFrame.from_dict(data)
# pp = pprint.PrettyPrinter(indent=4)
# pp.pprint(data)
# print(df)
# print(data.keys())

folios = len(data["folios"])
portfolio_dict = {
    "folio_id": "",
    "fund_id": "",
    "fund_name": "",
    "investment_amount": 0,
    "investment_date": "",
}
counter = 0
total = 0

df = pd.DataFrame(columns=["PAN", "Folio_number", "amfi", "isin", "scheme","transaction_amount","transaction_balance","transaction_date","transaction_nav",
                           "transaction_type","transaction_units", "statement_date","stmt_date_nav","value"])
for i in range(folios):
    schemes = len(data["folios"][i]["schemes"])
#     print(i)

    if data["folios"][i]["PAN"] == "BGXPS5380R":

        for scheme in range(schemes):
            transactions = len(data["folios"][i]["schemes"][scheme]["transactions"])
            try:
               
                for transaction in range(transactions):
                    df.loc[len(df.index)] = [
                        data["folios"][i]["PAN"],
                        data["folios"][i]["folio"],
                        data["folios"][i]["schemes"][scheme]["amfi"],
                        data["folios"][i]["schemes"][scheme]["isin"],
                        data["folios"][i]["schemes"][scheme]["scheme"],
                        data["folios"][i]["schemes"][scheme]["transactions"][transaction]["amount"],
                        data["folios"][i]["schemes"][scheme]["transactions"][transaction]["balance"],
                        data["folios"][i]["schemes"][scheme]["transactions"][transaction]["date"],
                        data["folios"][i]["schemes"][scheme]["transactions"][transaction]["nav"],
                        data["folios"][i]["schemes"][scheme]["transactions"][transaction]["type"],
                        data["folios"][i]["schemes"][scheme]["transactions"][transaction]["units"],

                        data["folios"][i]["schemes"][scheme]["valuation"]["date"],
                        data["folios"][i]["schemes"][scheme]["valuation"]["nav"],
                        data["folios"][i]["schemes"][scheme]["valuation"]["value"],
                    ]
            except Exception as e:
                print("Exception caught :",e)
                
                

            
            total += data["folios"][i]["schemes"][scheme]["valuation"]["value"]
            counter += 1

print("****** Total Value : ", total, "  ***** counter : ", counter)
# display(df)
df.to_csv("stmt.csv")
# Out:
# {'cas_type': 'DETAILED', 'statement_period': {'from': '01-Dec-2006', 'to': '30-Dec-2022'}, 'folios': [{'folio': '1015491651', 'amc': 'Aditya Birla Sun Life Mutual Fund', 'PAN': 'BGXPS5380R', 'KYC': 'OK', 'PANKYC': 'OK', 'schemes': [{'scheme': 'Aditya Birla Sun Life Dividend Yield Fund - Growth-Regular Plan', 'advisor': 'HDFCPB', 'rta_code': 'B261G', 'type': 'EQUITY', 'rta': 'CAMS', 'isin': 'INF209K01405', 'amfi': '101738', 'open': Decimal('0.000'), 'close': Decimal('0.000'), 'close_calculated': Decimal('0.0000'), 'valuation': {'date': datetime.date(2022, 12, 29), 'value': Decimal('0.00'), 'nav': Decimal('270.58')}, 'transactions': [{'date': datetime.date(2010, 7, 5), 'description': 'Purchase', 'amount': Decimal('5000.00'), 'units': Decimal('62.767'), 'nav': Decimal('79.66'), 'balance': Decimal('62.767'), 'type': 'PURCHASE', 'dividend_rate': None}, {'date': datetime.date(2010, 10, 6), 'description': 'Redemption - Electronic Payment', 'amount': Decimal('-5825.47'), 'units': Decimal('-62.7670'), 'nav': Decimal('93.05'), 'balance': Decimal('0.000'), 'type': 'REDEMPTION', 'dividend_rate': None}, {'date': datetime.date(2010, 10, 6), 'description': '*** STT Paid ***', 'amount': Decimal('15.00'), 'units': None, 'nav': None, 'balance': None, 'type': 'STT_TAX', 'dividend_rate': None}, {'date': datetime.date(2010, 10, 6), 'description': 'Purchase 18-Oct-2010', 'amount': Decimal('5000.00'), 'units': Decimal('53.476'), 'nav': Decimal('93.50'), 'balance': Decimal('53.476'), 'type': 'PURCHASE', 'dividend_rate': None}, {'date': datetime.date(2010, 11, 19), 'description': 'Purchase', 'amount': Decimal('2000.00'), 'units': Decimal('21.853'), 'nav': Decimal('91.52'), 'balance': Decimal('75.329'), 'type': 'PURCHASE', 'dividend_rate': None}, {'date': datetime.date(2012, 9, 27), 'description': 'Redemption - Electronic Payment', 'amount': Decimal('-6622.49'), 'units': Decimal('-75.329'), 'nav': Decimal('88.14'), 'balance': Decimal('0.000'), 'type': 'REDEMPTION', 'dividend_rate': None}, {'date': datetime.date(2012, 9, 27), 'description': '*** STT Paid ***', 'amount': Decimal('17.00'), 'units': None, 'nav': None, 'balance': None, 'type': 'STT_TAX', 'dividend_rate': None}]}, {'scheme': 'Aditya Birla Sun Life Focused Equity Fund - Growth-Regular Plan', 'advisor': 'HDFCPB', 'rta_code': 'B292G', 'type': 'EQUITY', 'rta': 'CAMS', 'isin': 'INF209K01462', 'amfi': '103309', 'open': Decimal('0.000'), 'close': Decimal('4347.941'), 'close_calculated': Decimal('4347.941'), 'valuation': {'date': datetime.date(2022, 12, 29), 'value': Decimal('405531.15'), 'nav': Decimal('93.2697')}, 'transactions': [{'date': datetime.date(2018, 1, 10), 'description': 'Purchase SIP', 'amount': Decimal('8000.00'), 'units': Decimal('134.784'), 'nav': Decimal('59.3544'), 'balance': Decimal('134.784'), 'type': 'PURCHASE_SIP', 'dividend_rate': None}, {'date': datetime.date(2018, 2, 12), 'description': 'Purchase SIP', 'amount': Decimal('8000.00'), 'units': Decimal('138.494'), 'nav': Decimal('57.7642'), 'balance': Decimal('273.278'), 'type': 'PURCHASE_SIP', 'dividend_rate': None}, {'date': datetime.date(2018, 3, 12), 'description': 'Purchase SIP', 'amount': Decimal('8000.00'), 'units': Decimal('142.619'), 'nav': Decimal('56.0935'), 'balance': Decimal('415.897'), 'type': 'PURCHASE_SIP', 'dividend_rate': None}, {'date': datetime.date(2018, 4, 10), 'description': 'Purchase SIP', 'amount': Decimal('8000.00'), 'units': Decimal('141.832'), 'nav': Decimal('56.4046'), 'balance': Decimal('557.729'), 'type': 'PURCHASE_SIP', 'dividend_rate': None}, {'date': datetime.date(2018, 5, 10), 'description': 'Purchase SIP', 'amount': Decimal('8000.00'), 'units': Decimal('140.028'), 'nav': Decimal('57.1313'), 'balance': Decimal('697.757'), 'type': 'PURCHASE_SIP', 'dividend_rate': None}, {'date': datetime.date(2018, 6, 11), 'description': 'Purchase SIP', 'amount': Decimal('8000.00'), 'units': Decimal('140.584'), 'nav': Decimal('56.9055'), 'balance': Decimal('838.341'), 'type': 'PURCHASE_SIP', 'dividend_rate': No ...
# ****** Total Value :  6003995.07   ***** counter :  51

# %%
df.sort_values(by=['transaction_date'],ascending=False).head(20)
# Out:
#             PAN  Folio_number    amfi          isin  \
# 470  BGXPS5380R   51015774412  120823  INF966L01614
# 148  BGXPS5380R  12637967/ 04  102760  INF179K01574
# 580  BGXPS5380R  599321232753  100822  INF789F01JN2
# 437  BGXPS5380R  499269732005  118741  INF204K01H36
# 439  BGXPS5380R  499269732005  118741  INF204K01H36
# 438  BGXPS5380R  499269732005  118741  INF204K01H36
# 423  BGXPS5380R  499146554216  113177  INF204K01HY3
# 436  BGXPS5380R  499269732005  118741  INF204K01H36
# 435  BGXPS5380R  499269732005  118741  INF204K01H36
# 451  BGXPS5380R  499269732005  146513  INF204KB1X25
# 445  BGXPS5380R  499269732005  148726  INF204KB18Z7
# 464  BGXPS5380R  499269732005  118796  INF204K01B32
# 457  BGXPS5380R  499269732005  148519  INF204KB15W0
# 469  BGXPS5380R   51015774412  120823  INF966L01614
# 468  BGXPS5380R   51015774412  120823  INF966L01614
# 146  BGXPS5380R  12637967/ 04  102760  INF179K01574
# 147  BGXPS5380R  12637967/ 04  102760  INF179K01574
# 579  BGXPS5380R  599321232753  100822  INF789F01JN2
# 578  BGXPS5380R  599321232753  100822  INF789F01JN2
# 422  BGXPS5380R  499146554216  113177  INF204K01HY3
#
#                                                 scheme transaction_amount  \
# 470                         Quant Active Fund - Growth               1.75
# 148       HDFC Focused 30 Fund - Regular Plan - Growth               1.50
# 580             UTI Nifty 50 Index Fund - Regular Plan               1.50
# 437  NIPPON INDIA INDEX FUND - NIFTY 50 PLAN - DIRE...               0.06
# 439  NIPPON INDIA INDEX FUND - NIFTY 50 PLAN - DIRE...               0.06
# 438  NIPPON INDIA INDEX FUND - NIFTY 50 PLAN - DIRE...            1162.94
# 423  NIPPON INDIA SMALL CAP FUND - GROWTH PLAN GROW...               1.50
# 436  NIPPON INDIA INDEX FUND - NIFTY 50 PLAN - DIRE...            1227.94
# 435  NIPPON INDIA INDEX FUND - NIFTY 50 PLAN - DIRE...               0.05
# 451  NIPPON INDIA NIFTY NEXT 50 JUNIOR BEES FOF - D...               0.13
# 445  NIPPON INDIA NIFTY MIDCAP 150 INDEX FUND - DIR...               0.01
# 464  NIPPON INDIA SHORT TERM FUND - DIRECT GROWTH P...            -959.00
# 457  NIPPON INDIA NIFTY SMALLCAP 250 INDEX FUND - D...               0.01
# 469                         Quant Active Fund - Growth           34998.25
# 468                         Quant Active Fund - Growth               1.25
# 146       HDFC Focused 30 Fund - Regular Plan - Growth               1.50
# 147       HDFC Focused 30 Fund - Regular Plan - Growth           29998.50
# 579             UTI Nifty 50 Index Fund - Regular Plan           29998.50
# 578             UTI Nifty 50 Index Fund - Regular Plan               1.50
# 422  NIPPON INDIA SMALL CAP FUND - GROWTH PLAN GROW...           29998.50
#
#     transaction_balance transaction_date transaction_nav transaction_type  \
# 470                None       2022-12-20            None   STAMP_DUTY_TAX
# 148                None       2022-12-12            None   STAMP_DUTY_TAX
# 580                None       2022-12-07            None   STAMP_DUTY_TAX
# 437                None       2022-11-28            None   STAMP_DUTY_TAX
# 439                None       2022-11-28            None   STAMP_DUTY_TAX
# 438             256.382       2022-11-28         33.0650         PURCHASE
# 423                None       2022-11-28            None   STAMP_DUTY_TAX
# 436             221.211       2022-11-24         33.0650         PURCHASE
# 435                None       2022-11-24            None   STAMP_DUTY_TAX
# 451                None       2022-11-24            None   STAMP_DUTY_TAX
# 445                None       2022-11-23            None          STT_TAX
# 464             171.964       2022-11-23         46.4832       REDEMPTION
# 457                None       2022-11-23            None          STT_TAX
# 469             178.353       2022-11-21        484.6971     PURCHASE_SIP
# 468                None       2022-11-21            None   STAMP_DUTY_TAX
# 146                None       2022-11-10            None   STAMP_DUTY_TAX
# 147            2194.766       2022-11-10         136.655     PURCHASE_SIP
# 579            1252.058       2022-11-07        124.7569     PURCHASE_SIP
# 578                None       2022-11-07            None   STAMP_DUTY_TAX
# 422            6484.849       2022-10-28         94.6448     PURCHASE_SIP
#
#     transaction_units statement_date stmt_date_nav      value
# 470              None     2022-12-29      483.7068   86270.56
# 148              None     2022-12-29       134.397  294969.97
# 580              None     2022-12-29      122.2483  153061.96
# 437              None     2022-12-29       32.3973    8306.08
# 439              None     2022-12-29       32.3973    8306.08
# 438            35.171     2022-12-29       32.3973    8306.08
# 423              None     2022-12-29       92.4259  599368.01
# 436            37.137     2022-12-29       32.3973    8306.08
# 435              None     2022-12-29       32.3973    8306.08
# 451              None     2022-12-29       15.6937    7144.34
# 445              None     2022-12-29       13.5967    3630.99
# 464           -20.631     2022-12-29       46.7797    8044.42
# 457              None     2022-12-29       18.7514    3631.92
# 469            72.206     2022-12-29      483.7068   86270.56
# 468              None     2022-12-29      483.7068   86270.56
# 146              None     2022-12-29       134.397  294969.97
# 147           219.520     2022-12-29       134.397  294969.97
# 579           240.456     2022-12-29      122.2483  153061.96
# 578              None     2022-12-29      122.2483  153061.96
# 422           316.959     2022-12-29       92.4259  599368.01
