# %%
# To import stock prices
import pandas_datareader as pdr
# To plot
import datetime as dt
import matplotlib.pyplot as plt
df = pdr.get_data_yahoo('RELIANCE.NS','2022-05-01', dt.date.today())
fig, ax = plt.subplots()
ax.plot(df.Close, color='black')

# %%
df = pdr.get_data_yahoo('INFY.NS','2022-05-01', dt.date.today())
fig, ax = plt.subplots()
ax.plot(df.Close, color='black')


price_min = df.Close.min()
price_max = df.Close.max()

print(price_max)
print(price_min)
# Fibonacci Levels considering original trend as upward move
diff = price_max - price_min
level1 = price_max - 0.236 * diff
level2 = price_max - 0.382 * diff
level3 = price_max - 0.618 * diff

print ("Level", "Price")
print ("0 ", price_max)
print ("0.236", level1)
print ("0.382", level2)
print ("0.618", level3)
print ("1 ", price_min)

ax.axhspan(level1, price_min, alpha=0.4, color='lightsalmon')
ax.axhspan(level2, level1, alpha=0.5, color='palegoldenrod')
ax.axhspan(level3, level2, alpha=0.5, color='palegreen')
ax.axhspan(price_max, level3, alpha=0.5, color='powderblue')

plt.ylabel("Price")
plt.xlabel("Date")
plt.legend(loc=2)
plt.show()
# Out:
# No handles with labels found to put in legend.
# 1585.1500244140625
# 1410.449951171875
# Level Price
# 0  1585.1500244140625
# 0.236 1543.9208071289063
# 0.382 1518.4145964355469
# 0.618 1477.1853791503906
# 1  1410.449951171875
