# %%
import twelvedata

# Get your API key from https://twelvedata.com/
api_key = "5d5b0b91a14e4738b56003e7799dacaa"

# Initialize the Twelve Data client
client = twelvedata.TDClient(apikey=api_key)

# Fetch the stock data for TCS
tcs_data = client.time_series(
    symbol="TCS.NS",
    interval="1min",
    outputsize=100,
)

# Print the stock data
tcs_data.as_pandas()
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# <ipython-input-16-4de65b7569aa> in <module>
#      15
#      16 # Print the stock data
# ---> 17 tcs_data.as_pandas()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/twelvedata/time_series.py in as_pandas(self, **kwargs)
#     112
#     113         if self.price_endpoint_enabled:
# --> 114             df = self.price_endpoint.as_pandas()
#     115         else:
#     116             df = None
#
# ~/opt/anaconda3/lib/python3.8/site-packages/twelvedata/mixins.py in as_pandas(self, **kwargs)
#      42         assert hasattr(self, "as_json")
#      43
# ---> 44         data = self.as_json()
#      45         if hasattr(self, "is_batch") and self.is_batch:
#      46             df = convert_collection_to_pandas_multi_index(data)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/twelvedata/mixins.py in as_json(self)
# ...

# %%
# Out:
#                        open    high     low    close  volume
# datetime
# 2023-08-18 15:59:00  16.710  16.720  16.700  16.7200  129017
# 2023-08-18 15:58:00  16.705  16.710  16.700  16.7050  141192
# 2023-08-18 15:57:00  16.705  16.710  16.700  16.7050   33260
# 2023-08-18 15:56:00  16.705  16.705  16.700  16.7050   42928
# 2023-08-18 15:55:00  16.715  16.715  16.700  16.7085   72804
# ...                     ...     ...     ...      ...     ...
# 2023-08-18 14:24:00  16.695  16.700  16.690  16.6900    2943
# 2023-08-18 14:23:00  16.700  16.705  16.690  16.6900    5736
# 2023-08-18 14:22:00  16.700  16.705  16.695  16.7050    7617
# 2023-08-18 14:21:00  16.695  16.700  16.690  16.7000   15420
# 2023-08-18 14:20:00  16.695  16.695  16.690  16.6900    5941
#
# [100 rows x 5 columns]

# %%
# !pip install twelvedata
# Out:
# ...
#      |████████████████████████████████| 45 kB 295 kB/s eta 0:00:01
# ...
