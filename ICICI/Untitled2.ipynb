# %%
from breeze_connect import BreezeConnect

from datetime import datetime

class BreezeSession():
    def __init__(self):
        #if BREEZE_SESSION is None:
        self.acc = BreezeAccount.objects.all().last()
        self.breeze = BreezeConnect(api_key=self.acc.api_key)
        self.breeze.generate_session(api_secret=self.acc.api_secret,session_token=self.acc.session_token)
        #BREEZE_SESSION = self.breeze
        #else:
           #self.breeze = BREEZE_SESSION
    
    def get_data(self):
        data = self.breeze.get_historical_data_v2('1minute','2023-07-01T07:00:00.000Z','2023-07-10T07:00:00.000Z','NIFTY','NSE')
        data2 = self.breeze.get_historical_data_v2('1minute','2023-07-01T07:00:00.000Z','2023-07-10T07:00:00.000Z','NIFTY','NFO','futures','2023-07-27T07:00:00.000Z')
        print(data)
# Out:
# {'Meta Data': {'1. Information': 'Intraday (5min) open, high, low, close prices and volume', '2. Symbol': 'IBM', '3. Last Refreshed': '2023-08-18 19:55:00', '4. Interval': '5min', '5. Output Size': 'Compact', '6. Time Zone': 'US/Eastern'}, 'Time Series (5min)': {'2023-08-18 19:55:00': {'1. open': '141.4800', '2. high': '141.5000', '3. low': '141.4800', '4. close': '141.5000', '5. volume': '94'}, '2023-08-18 19:40:00': {'1. open': '141.3000', '2. high': '141.3000', '3. low': '141.3000', '4. close': '141.3000', '5. volume': '7'}, '2023-08-18 19:30:00': {'1. open': '141.4100', '2. high': '141.4100', '3. low': '141.4100', '4. close': '141.4100', '5. volume': '9'}, '2023-08-18 19:20:00': {'1. open': '141.4100', '2. high': '141.4100', '3. low': '141.4100', '4. close': '141.4100', '5. volume': '6'}, '2023-08-18 19:15:00': {'1. open': '141.2800', '2. high': '141.2800', '3. low': '141.2800', '4. close': '141.2800', '5. volume': '7'}, '2023-08-18 19:00:00': {'1. open': '141.4100', '2. high': '141.4100', '3. low': '141.4100', '4. close': '141.4100', '5. volume': '980167'}, '2023-08-18 18:55:00': {'1. open': '141.5000', '2. high': '141.5000', '3. low': '141.5000', '4. close': '141.5000', '5. volume': '100'}, '2023-08-18 18:40:00': {'1. open': '141.5000', '2. high': '141.5000', '3. low': '141.5000', '4. close': '141.5000', '5. volume': '20'}, '2023-08-18 18:30:00': {'1. open': '141.4100', '2. high': '141.4100', '3. low': '141.2700', '4. close': '141.2700', '5. volume': '980667'}, '2023-08-18 18:25:00': {'1. open': '141.2700', '2. high': '141.2700', '3. low': '141.2700', '4. close': '141.2700', '5. volume': '3'}, '2023-08-18 18:15:00': {'1. open': '141.2700', '2. high': '141.2700', '3. low': '141.2700', '4. close': '141.2700', '5. volume': '2'}, '2023-08-18 17:55:00': {'1. open': '141.5000', '2. high': '141.5000', '3. low': '141.5000', '4. close': '141.5000', '5. volume': '3'}, '2023-08-18 17:50:00': {'1. open': '141.2700', '2. high': '141.2700', '3. low': '141.2700', '4. close': '141.2700', '5. volume': '9'}, '2023-08-18 17:40:00': {'1. open': '141.2700', '2. high': '141.2700', '3. low': '141.2700', '4. close': '141.2700', '5. volume': '500'}, '2023-08-18 17:35:00': {'1. open': '141.4100', '2. high': '141.4100', '3. low': '141.4100', '4. close': '141.4100', '5. volume': '1'}, '2023-08-18 17:30:00': {'1. open': '141.4100', '2. high': '141.5000', '3. low': '141.4100', '4. close': '141.4100', '5. volume': '1434'}, '2023-08-18 17:25:00': {'1. open': '141.4100', '2. high': '141.4100', '3. low': '141.3100', '4. close': '141.3100', '5. volume': '195'}, '2023-08-18 17:15:00': {'1. open': '141.2700', '2. high': '141.2700', '3. low': '141.2700', '4. close': '141.2700', '5. volume': '31'}, '2023-08-18 17:00:00': {'1. open': '141.2700', '2. high': '141.2700', '3. low': '141.2700', '4. close': '141.2700', '5. volume': '1'}, '2023-08-18 16:55:00': {'1. open': '141.2700', '2. high': '141.2700', '3. low': '141.2600', '4. close': '141.2600', '5. volume': '31'}, '2023-08-18 16:50:00': {'1. open': '141.2600', '2. high': '141.4100', '3. low': '141.2600', '4. close': '141.4100', '5. volume': '201'}, '2023-08-18 16:45:00': {'1. open': '141.2620', '2. high': '141.4100', '3. low': '141.2620', '4. close': '141.4100', '5. volume': '2715'}, '2023-08-18 16:40:00': {'1. open': '141.4100', '2. high': '141.4100', '3. low': '141.4100', '4. close': '141.4100', '5. volume': '184127'}, '2023-08-18 16:30:00': {'1. open': '141.2600', '2. high': '141.2600', '3. low': '141.2600', '4. close': '141.2600', '5. volume': '201'}, '2023-08-18 16:25:00': {'1. open': '141.3500', '2. high': '141.3500', '3. low': '141.0300', '4. close': '141.0300', '5. volume': '335'}, '2023-08-18 16:20:00': {'1. open': '140.9640', '2. high': '141.3500', '3. low': '140.9640', '4. close': '141.3500', '5. volume': '252'}, '2023-08-18 16:15:00': {'1. open': '141.4100', '2. high': '141.4100', '3. low': '140.9200', '4. close': '140.9610', '5. volume': '2734'}, '2023-08-18 16:10:00': {'1. open': '141.4100', '2. ...

# %%
the_quotation
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-ae863b9ebee3> in <module>
# ----> 1 the_quotation
#
# NameError: name 'the_quotation' is not defined
