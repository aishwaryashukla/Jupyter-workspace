# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt

# %%
stocks_isin=['INE585B01010',
'INE238A01034',
'INE918I01018',
'INE040A01034',
'INE001A01036',
'INE123W01016',
'INE062A01020',
'INE217B01036',
'INE176B01034',
'INE117A01022',
'INE154A01025',
'INE785M01013',
'INE053A01029',
'INF109K012R6',
'INE009A01021',
'INE075A01022',
'INE081A01012',
'INE376G01013',
'INE600L01024',
'INE002A01018',
'INE849A01020',
'INE111A01025',
'INE586V01016']

# %%
df = pd.read_csv('EQUITY_L.csv')
df=df[df[' ISIN NUMBER'].isin(stocks_isin)]
stocks_list = df['SYMBOL'].tolist()
stocks_list_NSE = list(map(lambda x: x+".NS",stocks_list))
data1 = yf.download(stocks_list_NSE,start="2020-01-01",end="2020-12-14")
# Out:
# [*********************100%***********************]  22 of 22 completed

# %%
type(data1['Adj Close'])
close_price_df = data1['Adj Close']
close_price_df.head()
# Out:
#                  ABB.NS  AXISBANK.NS  BAJAJFINSV.NS   BIOCON.NS   CONCOR.NS  \
# Date
# 2019-12-31  1264.443359   754.099976    9388.081055  293.700012  562.783020
# 2020-01-01  1269.116455   748.700012    9373.190430  294.549988  563.865479
# 2020-01-02  1273.248291   756.950012    9500.268555  296.149994  562.881409
# 2020-01-03  1300.844360   742.950012    9340.607422  300.950012  560.618042
# 2020-01-06  1266.164917   723.250000    9037.627930  288.200012  553.237610
#
#             HAVELLS.NS      HDFC.NS  HDFCBANK.NS  INDHOTEL.NS     INFY.NS  \
# Date
# 2019-12-31  642.839294  2359.887939  1272.099976   144.078201  713.664429
# 2020-01-01  645.173584  2380.820557  1278.599976   143.283279  719.228088
# 2020-01-02  650.090637  2412.562256  1286.750000   146.661682  717.129578
# 2020-01-03  656.100342  2400.873047  1268.400024   144.972473  728.159302
# 2020-01-06  642.839294  2332.059082  1240.949951   140.153305  721.180298
#
#             ...  LALPATHLAB.NS    MARUTI.NS  PCJEWELLER.NS  RELIANCE.NS  \
# Date        ...
# 2019-12-31  ...    1484.553711  7302.909668      24.350000  1508.386353
# 2020-01-01  ...    1523.755615  7246.517090      24.299999  1503.952881
# 2020-01-02  ...    1525.047363  7264.505371      24.250000  1529.556763
# 2020-01-03  ...    1530.512817  7189.579102      24.250000  1531.399902
# 2020-01-06  ...    1521.768311  6979.617676      23.450001  1495.883179
#
#             SBILIFE.NS     SBIN.NS  TATASTEEL.NS   TCIEXP.NS    TRENT.NS  \
# Date
# 2019-12-31  961.599976  333.750000    460.123505  739.815063  526.255981
# 2020-01-01  976.400024  334.450012    455.932159  737.074463  528.751709
# 2020-01-02  969.349976  339.299988    472.600128  728.354370  540.431824
# 2020-01-03  975.099976  333.700012    471.479187  726.062195  534.991089
# 2020-01-06  983.099976  319.000000    461.293213  704.486145  529.051208
#
#               WIPRO.NS
# Date
# 2019-12-31  244.811661
# 2020-01-01  246.704010
# 2020-01-02  247.301605
# 2020-01-03  250.090347
# 2020-01-06  251.136124
#
# [5 rows x 22 columns]

# %%
# close_price_df['ABB.NS.MA10']=close_price_df['ABB.NS'].rolling(10).mean()
# type(close_price_df['ABB.NS'])
# close_price_df['ABB.NS.MA10']=close_price_df.loc[:,('ABB.NS')].rolling(10).mean()
# test = close_price_df.loc[:,('ABB.NS')].rolling(10).mean()
# close_price_df
for cusip in stocks_list_NSE:
    print(" cusip = {cusip}".format(cusip=cusip))
    ma10 = cusip+".MA10"
    ma50 = cusip+".MA50"
    close_price_df[ma10]=close_price_df.loc[:,(cusip)].rolling(10).mean()
    close_price_df[ma50]=close_price_df.loc[:,(cusip)].rolling(50).mean()
# Out:
#  cusip = ABB.NS
#  cusip = AXISBANK.NS
#  cusip = BAJAJFINSV.NS
#  cusip = BIOCON.NS
#  cusip = CONCOR.NS
#  cusip = HAVELLS.NS
#  cusip = HDFC.NS
#  cusip = HDFCBANK.NS
#  cusip = INDHOTEL.NS
#  cusip = INFY.NS
#  cusip = ITC.NS
#  cusip = KAJARIACER.NS
#  cusip = LALPATHLAB.NS
#  cusip = MARUTI.NS
#  cusip = PCJEWELLER.NS
#  cusip = RELIANCE.NS
#  cusip = SBILIFE.NS
#  cusip = SBIN.NS
#  cusip = TATASTEEL.NS
#  cusip = TCIEXP.NS
#  cusip = TRENT.NS
#  cusip = WIPRO.NS
# <ipython-input-9-9808c64063b6>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   close_price_df[ma10]=close_price_df.loc[:,(cusip)].rolling(10).mean()
# <ipython-input-9-9808c64063b6>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   close_price_df[ma50]=close_price_df.loc[:,(cusip)].rolling(50).mean()

# %%
close_price_df.columns
# Out:
# Index(['ABB.NS', 'AXISBANK.NS', 'BAJAJFINSV.NS', 'BIOCON.NS', 'CONCOR.NS',
#        'HAVELLS.NS', 'HDFC.NS', 'HDFCBANK.NS', 'INDHOTEL.NS', 'INFY.NS',
#        'ITC.NS', 'KAJARIACER.NS', 'LALPATHLAB.NS', 'MARUTI.NS',
#        'PCJEWELLER.NS', 'RELIANCE.NS', 'SBILIFE.NS', 'SBIN.NS', 'TATASTEEL.NS',
#        'TCIEXP.NS', 'TRENT.NS', 'WIPRO.NS', 'ABB.NS.MA10', 'AXISBANK.NS.MA10',
#        'BAJAJFINSV.NS.MA10', 'BIOCON.NS.MA10', 'CONCOR.NS.MA10',
#        'HAVELLS.NS.MA10', 'HDFC.NS.MA10', 'HDFCBANK.NS.MA10',
#        'INDHOTEL.NS.MA10', 'INFY.NS.MA10', 'ITC.NS.MA10', 'KAJARIACER.NS.MA10',
#        'LALPATHLAB.NS.MA10', 'MARUTI.NS.MA10', 'PCJEWELLER.NS.MA10',
#        'RELIANCE.NS.MA10', 'SBILIFE.NS.MA10', 'SBIN.NS.MA10',
#        'TATASTEEL.NS.MA10', 'TCIEXP.NS.MA10', 'TRENT.NS.MA10', 'WIPRO.NS.MA10',
#        'ABB.NS.MA50', 'AXISBANK.NS.MA50', 'BAJAJFINSV.NS.MA50',
#        'BIOCON.NS.MA50', 'CONCOR.NS.MA50', 'HAVELLS.NS.MA50', 'HDFC.NS.MA50',
#        'HDFCBANK.NS.MA50', 'INDHOTEL.NS.MA50', 'INFY.NS.MA50', 'ITC.NS.MA50',
#        'KAJARIACER.NS.MA50', 'LALPATHLAB.NS.MA50', 'MARUTI.NS.MA50',
#        'PCJEWELLER.NS.MA50', 'RELIANCE.NS.MA50', 'SBILIFE.NS.MA50',
#        'SBIN.NS.MA50', 'TATASTEEL.NS.MA50', 'TCIEXP.NS.MA50', 'TRENT.NS.MA50',
#        'WIPRO.NS.MA50'],
#       dtype='object')

# %%
for ticker in stocks_list_NSE:
    close_price_df[ticker+".MA10"].plot(label=ticker+'.MA10',title=ticker)
    close_price_df[ticker+".MA10"].plot(label=ticker+'.MA70',title=ticker)
    plt.legend()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\dev\Programs\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ABB.NS.NS.MA10'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-4364a8682f00> in <module>
#       1 for ticker in stocks_list_NSE:
# ----> 2     close_price_df[ticker+".NS.MA10"].plot(label=ticker+'.MA10',title=ticker)
#       3     close_price_df[ticker+".NS.MA10"].plot(label=ticker+'.MA70',title=ticker)
#       4     plt.legend()
#
# C:\dev\Programs\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# C:\dev\Programs\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'ABB.NS.NS.MA10'
